# %%
import wave
import matplotlib.pyplot as plt
import imp
import scipy.signal as sig
import numpy as np
import struct

import waveinfo
import pitch
import convert

# %matplotlib inline

# %%
imp.reload(waveinfo)
waveinfo.show_info("data/original/a.wav")
# Out:
# チャンネル数: 2
# サンプル幅: 2
# サンプリング周波数: 44100
# フレーム数: 105408
# パラメータ: (2, 2, 44100, 105408, 'NONE', 'not compressed')
# 長さ（秒）: 2.39020408163

# %%
result = sig.correlate([1,4,2,3,3,2], [1,4,2,3,3,2], mode="valid")
result[:]
# Out:
# array([43])

# %%
imp.reload(waveinfo)
wavefile = "a2.wav"
waveinfo.show_image(waveinfo.get_data("data/original/"+wavefile))
data = waveinfo.get_smoothed_data("data/original/"+wavefile)
waveinfo.show_image(data)
waveinfo.save_file("data/smoothed/smoothed_"+wavefile, data)

# %%
imp.reload(waveinfo)
imp.reload(pitch)
wavefile = "a2.wav"
data = waveinfo.get_smoothed_data("data/original/"+wavefile)

#pitch.find_first_peak(data)
pitch.find_peaks(data)[0][:10]
# Out:
# array([ 37,  96, 147, 228, 294, 359, 423, 484, 543, 607])

# %%
imp.reload(waveinfo)
imp.reload(pitch)
wavefile = "a2.wav"
data = waveinfo.get_smoothed_data("data/original/"+wavefile)

pitch.calc_pitch(data, 44100)
# Out:
# 280.891719745

# %%
imp.reload(convert)

buf_file = "data/nantehida/nantehida.raw"
results = convert.read_short(buf_file)

x = np.arange(len(results))
y = results

plt.plot(x, y)
plt.show()

# %%
imp.reload(convert)

buf_file = "data/nantehida/smoothed_nantehida.pitch"
results = convert.read_float(buf_file)

x = np.arange(len(results))
y = results

plt.plot(x, y)
plt.show()

# %%
imp.reload(convert)

buf_file = "data/nantehida/smoothed_nantehida2.pitch"
results = convert.read_float(buf_file)

x = np.arange(len(results))
y = results

plt.plot(x, y)
plt.show()

# %%
imp.reload(waveinfo)

ROUGHNESS1 = 100
ROUGHNESS2 = 500

filename = "nantehida"
data = waveinfo.get_data("data/"+filename+"/"+filename".wav")
waveinfo.show_image(data)
s_data = waveinfo.smoothing(data, ROUGHNESS1)
waveinfo.show_image(data)
waveinfo.save_file("data/nantehida/smoothed_"+wavefile, data)
# Out:
#   File "<ipython-input-99-63cea1596b46>", line 7
#     data = waveinfo.get_data("data/"+filename+"/"+filename".wav")
#                                                                ^
# SyntaxError: invalid syntax

# %%
imp.reload(waveinfo)
